# %% [markdown]
# # [NOME DA INSTITUIÇÃO]
# ## [NOME DA ESPECIALIZAÇÃO / PÓS-GRADUAÇÃO]
# ### Trabalho de Conclusão de Trilha de Aprendizagem: I
#
# **Estudante:** [Seu Nome Completo]
# **Matrícula:** [Sua Matrícula]
# **Data:** [Dia/Mês/Ano]

# %% [markdown]
# ### 1. Apresentação do Aluno e Contexto
# > **Orientação para o Estudante:**
# > Faça uma breve introdução sobre sua atuação profissional e o setor corporativo escolhido para este trabalho (ex: Logística, Varejo, Setor Bancário, RH, Manufatura). Explique por que o uso de IA é relevante para o nicho de mercado que você selecionou.

# %% [markdown]
# ### 2. Introdução e Definição do Problema
# > **Orientação para o Estudante:**
# > Descreva o problema corporativo observado. O que está gerando perda de receita, ineficiência ou gargalos? Tente focar em problemas que envolvam dados da empresa/instituição.
# >
# > **Exemplos de Cenários Aplicados:**
# > * **Logística:** Otimizar o carregamento de caminhões ou rotas de entrega pois o custo de entrega está alto devido a rotas ineficientes (**Busca A\*, UCS ou Programação Linear**).
# > * **Compliance/Jurídico:** Criar uma base de conhecimento para checar se contratos seguem normas vigentes (**Inferência por Resolução**).
# > * **RH:** Escalonamento de turnos de trabalho respeitando limites legais (**Satisfação de Restrições**).
# > * **Suporte ao Cliente:** O tempo de resposta para dúvidas técnicas é lento, exigindo uma **base de conhecimento** automatizada.
# > * **Engenharia Agrícola:** Otimização da irrigação e aplicação de defensivos em grandes lavouras com planejamento de rota para drones ou tratores autônomos visando o menor consumo de combustível e tempo (**A\* ou UCS**).
# > * **Direito:** Escalonamento de audiências, considerando a disponibilidade de advogados, especialidade e prazos processuais fatais (**Satisfação de Restrições - CSP**).
# > * **Saúde (HealthTech):** Alocação dinâmica de leitos de UTI para maximizar o atendimento em situações de alta demanda (surtos ou pandemias) **(Têmpera Simulada**).
# > * **Redes de Computadores:** Roteamento inteligente de pacotes para encontrar o caminho de menor latência em uma topologia de rede complexa sujeita a falhas de nós (**Algoritmo de Dijkstra/UCS**).
# > * **Ensino:** Personalização de trilhas de aprendizagem para alunos com diferentes níveis de conhecimento usando busca em espaço de estados gerando uma sequência de conteúdos (nós) que levem o aluno do estado inicial ao objetivo (domínio da matéria) no menor tempo possível (**Busca em Espaço de Estados**).
# > * **Gestão Escolar:** Montagem automática de grades horárias escolares, conciliando a disponibilidade de professores, salas específicas (laboratórios) e a carga horária dos alunos (**Satisfação de Restrições - CSP**).
# > * **Otimização do mix de produção fabril:** determinar a quantidade ideal de produtos A e B para maximizar o lucro, respeitando restrições lineares de matéria-prima e horas de maquinário ou problemas de transporte e distribuição logística (**Programação Linear**).
# > * **Otimização de Preço de um Produto:** descobrir o preço ideal de um produto para obter o maior lucro possível (**Programação Não Linear**).
# > * **Otimização do problema de rotas de frotas:**  Caixeiro Viajante com janelas de tempo de entrega, ou agendamento/escalonamento de tarefas em projetos complexos com restrições bi-objetivo - tempo e custo (**Algoritmo Genético**).
# > * **Ajuste de hiperparâmetros:** Ajuste de hiperparâmetros locais de controle de temperatura/pressão em caldeiras industriais automatizadas, ou otimização de campanhas de marketing digital onde pequenas variações contínuas nos investimentos em anúncios buscam o pico local de conversões (**Hill Climbing - Subida de Encosta**).

# %% [markdown]
# ### 3. Metodologia e Escolha da Técnica de IA
# > **Orientação para o Estudante:**
# > Justifique a escolha técnica. Explique qual técnica você escolheu e por que ela se adequa ao problema. Por que usar Busca em vez de Otimização? Por que Programação Linear e não Programação Não-Linear?
# >
# > * **Lógica:** Se o foco for criar uma base de conhecimento corporativa e usar Inferência por Resolução ou Model Checking para validar regras de compliance ou contratos.
# > * **Busca Competitiva/Heurística:** Se o foco for otimização de caminhos ou processos (ex: usar A* para encontrar a rota mais curta em um galpão ou UCS para menor custo de frete).
# > * **Otimização:** Se houver limitações de recursos (ex: Programação Linear para escala de funcionários ou Satisfação de Restrições para alocação de salas/maquinário).

# %% [markdown]
# ### 4. Implementação da Solução
# > **Orientação para o Estudante:**
# > Utilize as células de código abaixo para implementar sua solução (Esta seção precede suas células de código). Descreva brevemente como os dados foram estruturados e como o algoritmo foi parametrizado.
#
# > Para que seu trabalho tenha rigor científico e técnico, você deve formalizar os componentes do seu modelo antes de exibir o código, dependendo da técnica escolhida:
# > * **Se usou algoritmos de Busca (A, UCS, Largura, Gulosa)**: Defina explicitamente o **Estado Inicial** (onde o problema começa), o **Espaço de Estados**, as Ações possíveis (transições), o **Custo do Caminho** e o **Objetivo** (estado final desejado). Se aplicável, descreva a lógica por trás da sua **Função Heurística** ($h(n)$).
#
# > * **Se usou Programação Linear (PL) ou Não Linear (PNL)**: Identifique claramente as suas **Variáveis de Decisão** (o que o algoritmo precisa descobrir), a sua **Função Objetivo** (a equação matemática que você deseja maximizar, como lucro, ou minimizar, como custos/riscos) e o conjunto de inequações ou equações que representam as suas **Restrições** de recursos ou capacidade.
#
# > * **Se usou Satisfação de Restrições (CSP)**: Defina formalmente o trio **Variáveis** ($V$) (quais elementos precisam de atribuição), **Domínio** ($D$) (quais valores possíveis cada variável pode assumir) e **Restrições** ($R$) (quais são as regras rígidas que limitam as combinações de valores).
#
# > * **Se usou Algoritmo Genético (AG) ou Busca Local (Hill Climbing / Têmpera Simulada)**: Explique como os dados do problema foram codificados em um **Cromossomo/Indivíduo** (estrutura da solução), qual métrica foi usada como **Função de Fitness (Aptidão)** para avaliar a qualidade de cada resposta e quais foram os parâmetros dos operadores (tamanho da população, taxa de mutação/cruzamento ou critério de parada/resfriamento).

# %%
# Importação de bibliotecas
import numpy as np
# import pandas as pd

# Implementação do algoritmo escolhido (Ex: A*, Resolução, Gradiente Descendente)
def minha_solucao_ia():
    pass

# %% [markdown]
# ### 5. Resultados e Comparações
# > **Orientação para o Estudante:**
# > Apresente os dados gerados pela sua solução. É fundamental comparar:
# >
# > 1.   Cenário Atual (Baseline): Como o problema é resolvido hoje (manualmente ou por regra simples).
# >
# > 2.   Cenário IA: O desempenho da técnica escolhida (ex: Redução de 15% no custo, Acurácia de 92% na classificação, ou Tempo de execução do algoritmo de busca).
# >
# > Dica: Use tabelas para comparar métodos, por exemplo, a diferença de performance entre a Busca em Largura vs. Busca Gulosa para o seu problema específico.
# >
# > **Dicas de Visualização:**
# >
# 1.   **Algoritmos de Busca (A\*, UCS, Largura, Profundidade)**
#
# > O objetivo aqui é mostrar a eficiência da busca (encontrar o caminho mais curto processando o mínimo de estados possível).
# > *   **Gráfico de Barras Agrupadas** (`plt.bar` ou `ns.barplot`): Perfeito para comparar o **Tempo de Execução (segundos)** e a **Quantidade de Nós Expandidos** entre diferentes algoritmos rodando no mesmo cenário.
#
# > *   **Gráfico de Linha ou Grid / Heatmap** (`ns.heatmap`): Se o problema for espacial (como a rota de um drone agrícola ou robô de galpão), use um mapa de calor para plotar a grade do ambiente, destacando em cores diferentes o caminho final encontrado e os nós que foram "explorados" (frequentados) pelo algoritmo.
#
# 2.  **Otimização e Busca Local (Programação Linear/Não Linear, Hill Climbing, Algoritmo Genético)**
#
# > Aqui, o foco é demonstrar a evolução da resposta em direção ao ponto ideal e o respeito às restrições.
#
# > *   **Gráfico de Linha de Convergência** (`plt.plot`): Essencial para **Algoritmos Genéticos** e **Hill Climbing**. O eixo X exibe as Gerações/Iterações e o eixo Y mostra o valor do Fitness (Aptidão) ou da função objetivo. O gráfico deve ilustrar claramente a curva estabilizando (convergindo) para o topo.
#
# > *   **Gráfico de Área Empilhada** (`plt.stackplot`): Excelente para **Programação Linear** (Mix de Produção). Mostra visualmente como os recursos limitados (matéria-prima, horas de trabalho) foram consumidos e distribuídos entre os produtos para atingir o lucro máximo.
#
# 3. **Satisfação de Restrições (CSP)**
#
# > O desafio em CSP é mostrar que o algoritmo encontrou uma solução válida sem quebrar nenhuma regra de negócio rígida.
#
# > *    **Diagrama de Gantt ou Gráfico de Matriz** (`sns.heatmap`): Se o problema for escala de funcionários (RH) ou alocação de salas (Ensino/Saúde). O eixo X representa o tempo (turnos/horas) e o eixo Y as variáveis (funcionários/salas). As cores indicam as tarefas atribuídas, tornando evidente, visualmente, que nenhum funcionário foi alocado em dois lugares ao mesmo tempo (conflito zero).
#
# 4. **Lógica e Sistemas Baseados em Conhecimento**
#
# > Provar a consistência da base de conhecimento corporativa.
#
# > *    **Gráfico de Linha de Tempo ou Dispersão** (`plt.scatter`): Comparar o tempo que o motor de inferência (Resolução ou Model Checking) leva para validar uma regra à medida que o tamanho da base de conhecimento (número de fatos/cláusulas) cresce. Isso demonstra a escalabilidade do sistema para a empresa.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Exemplo de comparação visual (Template)
metodos = ['Tradicional', 'IA Aplicada']
valores = [100, 45] # Exemplo: Redução de custo

plt.figure(figsize=(8, 5))
sns.barplot(x=metodos, y=valores, palette='viridis', hue=metodos, legend=False)
plt.title('Comparativo de Custo Operacional')
plt.ylabel('Custo (R$)')
plt.show()

# %% [markdown]
# ### 6. Perspectiva de Evolução do Trabalho
#
# > **Orientação para o Estudante**: Nesta seção, o estudante fará um exercício puramente teórico e arquitetural. Imagine que sua empresa decidiu dar o próximo passo e substituir (ou complementar) a técnica que você implementou por uma **Rede Neural Profunda (Deep Learning)** voltada para **Classificação**. Sem precisar programar, discorra detalhadamente sobre como você estruturaria esse sistema de aprendizado de máquina respondendo aos seguintes pontos:
#
# > 1. **Organização e Engenharia dos Dados de Entrada ($X$)**:
# >> * Quais dados corporativos seriam coletados?
# >> * Como eles seriam transformados para que a rede neural os entenda? (Ex: Se forem textos/contratos, usaria *embeddings*? Se forem dados de RH/Tabelas, como faria a normalização de escala e o tratamento de variáveis categóricas? Se forem imagens agrícolas/industriais, qual seria a resolução e o tratamento de cor?).
#
# > 2. **Representação e Arquitetura Teórica da Rede**:
# >> * Que tipo de camada seria mais adequada para o seu problema? (Ex: Camadas Densas/Fully Connected para dados tabulares de finanças; Camadas Convolucionais - CNNs para imagens de saúde/agro; Camadas Recorrentes ou Transformers para sequências de texto/redes).
# >> * Quais seriam as **Camadas de Ativação** utilizadas no meio da rede (como a ReLU) e qual seria o papel delas para capturar as não-linearidades do seu problema corporativo?
#
# > 3. **Estrutura da Saída Esperada ($Y$)**:
# >> * Qual seria o formato da última camada da rede?
# >> * Como as classes seriam representadas? (Ex: Se for uma classificação binária como *Aprovado/Reprovado*, usaria um único neurônio com ativação **Sigmoid**? Se for classificação de múltiplas pragas ou múltiplos setores, usaria a função **Softmax** para gerar probabilidades para cada classe?).
# >> * Qual **Função de Perda** (*Loss Function*) seria a baliza matemática para o algoritmo calcular o erro e atualizar os pesos via **Gradiente Descendente**?

# %% [markdown]
# ### 7. Conclusões
# > **Orientação para o Estudante:**
# > Discorra sobre a viabilidade de implantar essa solução no ambiente corporativo real e quais foram os maiores aprendizados técnicos.
# >
# > Reflita sobre os ganhos obtidos. A solução é viável para produção em larga escala? Quais são as limitações técnicas encontradas?
# >
# > * **Exemplo de resposta**: "Embora a Tempera Simulada tenha encontrado uma solução ótima para a escala de produção, o tempo de processamento para bases de dados muito grandes exigiria uma computação distribuída."
# >
# > Quais são os 'casos de borda' (edge cases) onde a IA poderia falhar e exigir intervenção humana?
# >
# > * **Exemplo de resposta**: "Em um sistema de saúde, a IA pode falhar ao encontrar uma combinação raríssima de sintomas que não estava na base de treinamento, exigindo que o médico valide a decisão."
# >
# > Existe algum viés (bias) identificado nos dados que possa gerar decisões injustas por parte da IA (especialmente em Direito, Saúde ou RH)?
# >
# > * **Exemplo de resposta**: "No setor de RH, se os dados históricos favorecem contratações de uma região específica, o modelo pode excluir talentos de outras áreas injustamente. É necessário balancear a base de dados."
# >
# > Como a empresa pode explicar ao cliente final ou ao colaborador o motivo de uma decisão tomada por este algoritmo?
# >
# > * **Exemplo de resposta**: "Para o setor jurídico, a empresa pode mostrar o motor de inferência lógico para mostrar quais cláusulas do contrato foram determinantes para a reprovação da conformidade."

# %% [markdown]
# ### 8. Referências Bibliográficas
# > Orientação: Liste livros, artigos ou documentações (Python, Scikit-learn, etc) que fundamentaram seu trabalho.
# >
# > Dicas de Formatação:
# > Use as células de código (Code) logo após a seção 4 e 5 para demonstrar a execução.
# >
# > Utilize bibliotecas como matplotlib ou seaborn para gerar gráficos de comparação de resultados.
# >
# > Para equações matemáticas, use LaTeX (Exemplo: $f(x) = x^2$)

# %%
# use capture para esconder msgs de log na saída da célula
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %%
# cópia do seu notebook para a área de trabalho provisória /content
# %%capture
# !cp "/content/drive/MyDrive/Colab Notebooks/esp-IA/Template_Trabalho_Trilha-I.ipynb" /content/Template_Trabalho_Trilha-I.ipynb

# %%
# instalar componentes conversor para pdf
# %%capture
# 1. Instala a ferramenta de conversão (se necessário)
# !pip install nbconvert

# %%
# 2. Converte o notebook atual para HTML
# Substitua 'meu_notebook.ipynb' pelo nome exato do seu arquivo no Colab
# !jupyter nbconvert --to html Template_Trabalho_Trilha-I.ipynb
# Out:
# [NbConvertApp] Converting notebook Template_Trabalho_Trilha-I.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 326717 bytes to Template_Trabalho_Trilha-I.html
